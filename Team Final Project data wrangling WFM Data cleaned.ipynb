# %% [markdown]
# # WFH Data Cleaned - Coding for Final Project done by La-Vie & Vanessa

# %% [markdown]
# # Import Libraries
# ### Specific libraries are needed to run specific code

# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Load Data
# ### Imperative to load data for staticial analysis

# %%
df = pd.read_csv('/Users/chercher/Desktop/WFH Data Cleaned Upload.csv')

# %% [markdown]
# ## Print the head of the data to verify it is the correct dataset

# %%
df.head()
# Out:
#    ID Prior_WFH             Devices      Device_owner  \
# 0   5       Yes             Laptop;  Corporate assets
# 1   6       Yes             Laptop;  Corporate assets
# 2   7       Yes  Laptop;Smartphone;   Personal assets
# 3   8       Yes             Laptop;  Corporate assets
# 4   9       Yes  Laptop;Smartphone;  Corporate assets
#
#                                        Obtain_access New_apps Collab_solution  \
# 0  Remote connection to your workstation (e.g. Te...       No             Yes
# 1                              No special provisions       No             Yes
# 2                              No special provisions       No              No
# 3                              No special provisions       No              No
# 4                                         VPN access       No             Yes
#
#   Prefer_WFH Productivity Collab_colleagues Satisfaction_with_approach  \
# 0   Disagree    Undecided          Disagree                      Agree
# ...

# %% [markdown]
# ## Remove NULL values because they prohibit statitical analysis
# ### first show which columns have null values and how many

# %%
df.isnull().sum()
# Out:
# ID                            0
# Prior_WFH                     0
# Devices                       0
# Device_owner                  0
# Obtain_access                 0
# New_apps                      0
# Collab_solution               0
# Prefer_WFH                    0
# Productivity                  0
# Collab_colleagues             0
# Satisfaction_with_approach    0
# Tech_support                  0
# Proud_WFO                     0
# Proper_access                 0
# Age                           2
# Education                     3
# Business_domain               0
# Title                         0
# dtype: int64

# %% [markdown]
# ## Null values are in the age (2) & education (3) columns. Code to remove those using dropna()
# ### (inplace=True) used since I working in the original variable instead of renaming the variable

# %%
df.dropna(inplace=True)

# %% [markdown]
# ## Check to make sure all null values are gone - if it worked moving on to re-coding

# %%
df.isnull().sum()
# Out:
# ID                            0
# Prior_WFH                     0
# Devices                       0
# Device_owner                  0
# Obtain_access                 0
# New_apps                      0
# Collab_solution               0
# Prefer_WFH                    0
# Productivity                  0
# Collab_colleagues             0
# Satisfaction_with_approach    0
# Tech_support                  0
# Proud_WFO                     0
# Proper_access                 0
# Age                           0
# Education                     0
# Business_domain               0
# Title                         0
# dtype: int64

# %% [markdown]
# ## Data Recoding - converting categorical values to integers for statitical analysis

# %% [markdown]
# ### Prior to the COVID-19 crisis, were you able to work from home?
# #### Use value_counts() to discover how many answered the question, how and the data type

# %%
df.Prior_WFH.value_counts()
# Out:
# Yes    198
# No      63
# Name: Prior_WFH, dtype: int64

# %% [markdown]
# #### create a new column of recoded data and add to the data set

# %%
def Prior_WFH_recode (series):
    if series == "No":
        return 0
    if series == "Yes":
        return 1
df["Prior_WFHR"]= df["Prior_WFH"].apply(Prior_WFH_recode)

# %% [markdown]
# #### print the data frame to verify the recoded column was added to the data

# %%
df.head()
# Out:
#    ID Prior_WFH             Devices      Device_owner  \
# 0   5       Yes             Laptop;  Corporate assets
# 1   6       Yes             Laptop;  Corporate assets
# 2   7       Yes  Laptop;Smartphone;   Personal assets
# 3   8       Yes             Laptop;  Corporate assets
# 4   9       Yes  Laptop;Smartphone;  Corporate assets
#
#                                        Obtain_access New_apps Collab_solution  \
# 0  Remote connection to your workstation (e.g. Te...       No             Yes
# 1                              No special provisions       No             Yes
# 2                              No special provisions       No              No
# 3                              No special provisions       No              No
# 4                                         VPN access       No             Yes
#
#   Prefer_WFH Productivity Collab_colleagues Satisfaction_with_approach  \
# 0   Disagree    Undecided          Disagree                      Agree
# ...

# %% [markdown]
# ### What kind of devices are you using to connect to your corporate working environment?

# %% [markdown]
# #### Determine levels for Devices variable

# %%
df.Devices.value_counts()
# Out:
# Laptop;                                    155
# Laptop;Smartphone;                          55
# Desktop;                                    16
# Desktop;Laptop;                             12
# Desktop;Laptop;Tablet;Smartphone;            8
# Laptop;Tablet;                               4
# Laptop;Tablet;Smartphone;                    4
# Desktop;Laptop;Smartphone;                   4
# Smartphone;                                  1
# Desktop;Smartphone;                          1
# Desktop;Laptop;Tablet;Smartphone;Other;      1
# Name: Devices, dtype: int64

# %% [markdown]
# #### Recoding for Devices variable

# %%
def Devices_recode (series):
    if series == "Laptop;":
        return 0
    if series == "Laptop;Smartphone;":
        return 1
    if series == "Desktop;":
        return 2
    if series == "Desktop;Laptop;":
        return 3
    if series == "Desktop;Laptop;Tablet;Smartphone;":
        return 4
    if series == "Laptop;Tablet;":
        return 5
    if series == "Laptop;Tablet;Smartphone;":
        return 6
    if series == "Desktop;Laptop;Smartphone;":
        return 7
    if series == "Desktop;Laptop;Tablet;Smartphone;Other;":
        return 8
    if series == "Desktop;Smartphone;":
        return 9
    if series == "Smartphone;":
        return 10
    
df["DevicesR"] = df["Devices"].apply(Devices_recode)

# %% [markdown]
# #### verify recoding applied for Devices variable

# %%
df.head()
# Out:
#    ID Prior_WFH             Devices      Device_owner  \
# 0   5       Yes             Laptop;  Corporate assets
# 1   6       Yes             Laptop;  Corporate assets
# 2   7       Yes  Laptop;Smartphone;   Personal assets
# 3   8       Yes             Laptop;  Corporate assets
# 4   9       Yes  Laptop;Smartphone;  Corporate assets
#
#                                        Obtain_access New_apps Collab_solution  \
# 0  Remote connection to your workstation (e.g. Te...       No             Yes
# 1                              No special provisions       No             Yes
# 2                              No special provisions       No              No
# 3                              No special provisions       No              No
# 4                                         VPN access       No             Yes
#
#   Prefer_WFH Productivity Collab_colleagues Satisfaction_with_approach  \
# 0   Disagree    Undecided          Disagree                      Agree
# ...

# %% [markdown]
# #### Use .unique() to show recoded values
# #### original array (0, nan, 2, 10) the nan = 1,3,4,5,6,7,8,9

# %%
df['DevicesR'].unique()
# Out:
# array([ 0,  1,  2,  6,  7,  5,  3,  4,  8,  9, 10])

# %% [markdown]
# #### Copy/paste the categories and replace the text in the recode above

# %%
df['Devices'].unique()
# Out:
# array(['Laptop;', 'Laptop;Smartphone;', 'Desktop;',
#        'Laptop;Tablet;Smartphone;', 'Desktop;Laptop;Smartphone;',
#        'Laptop;Tablet;', 'Desktop;Laptop;',
#        'Desktop;Laptop;Tablet;Smartphone;',
#        'Desktop;Laptop;Tablet;Smartphone;Other;', 'Desktop;Smartphone;',
#        'Smartphone;'], dtype=object)

# %% [markdown]
# #### check to see if the nan is truly removed

# %%
df.isnull().sum()
# Out:
# ID                            0
# Prior_WFH                     0
# Devices                       0
# Device_owner                  0
# Obtain_access                 0
# New_apps                      0
# Collab_solution               0
# Prefer_WFH                    0
# Productivity                  0
# Collab_colleagues             0
# Satisfaction_with_approach    0
# Tech_support                  0
# Proud_WFO                     0
# Proper_access                 0
# Age                           0
# Education                     0
# Business_domain               0
# Title                         0
# Prior_WFHR                    0
# DevicesR                      0
# dtype: int64

# %% [markdown]
# ### Are the devices corporate or personal assets?
# #### Use value_counts() to discover how many answered the question, how and the data type

# %%
df.Device_owner.value_counts()
# Out:
# Corporate assets    166
# Personal assets      95
# Name: Device_owner, dtype: int64

# %% [markdown]
# #### create a new column of recoded data and add to the data set

# %%
def Device_owner_recode (series):
    if series == "Corporate assets":
        return 0
    if series == "Personal assets":
        return 1
df["Device_ownerR"]= df["Device_owner"].apply(Device_owner_recode)

# %% [markdown]
# #### print the data frame to verify the recoded column was added to the data

# %%
df.head()
# Out:
#    ID Prior_WFH             Devices      Device_owner  \
# 0   5       Yes             Laptop;  Corporate assets
# 1   6       Yes             Laptop;  Corporate assets
# 2   7       Yes  Laptop;Smartphone;   Personal assets
# 3   8       Yes             Laptop;  Corporate assets
# 4   9       Yes  Laptop;Smartphone;  Corporate assets
#
#                                        Obtain_access New_apps Collab_solution  \
# 0  Remote connection to your workstation (e.g. Te...       No             Yes
# 1                              No special provisions       No             Yes
# 2                              No special provisions       No              No
# 3                              No special provisions       No              No
# 4                                         VPN access       No             Yes
#
#   Prefer_WFH Productivity Collab_colleagues  ...    Tech_support  \
# 0   Disagree    Undecided          Disagree  ...           Agree
# ...

# %% [markdown]
# ### How do you obtain access to your corporate working environment?

# %% [markdown]
# #### Determine levels for Obtain_access variable

# %%
df.Obtain_access.value_counts()
# Out:
# Using VPN                                                        167
# Using 3rd party cloud solutions (e.g. G Cloud, Microsoft 365)     35
# Direct access                                                     29
# Other                                                             13
# No Access                                                         11
# No special provisions                                              4
# Remote connection to your workstation (e.g. TeamViewer)            1
# VPN access                                                         1
# Name: Obtain_access, dtype: int64

# %% [markdown]
# #### Recoding for Obtain_access variable

# %%
def Obtain_access_recode (series):
    if series == "Using VPN ":
        return 0
    if series == "Using 3rd party cloud solutions (e.g. G Cloud, Microsoft 365)":
        return 1
    if series == "Direct access":
        return 2
    if series == "Other":
        return 3
    if series == "No Access":
        return 4
    if series == "No special provisions":
        return 5
    if series == "VPN access":
        return 6
    if series == "Remote connection to your workstation (e.g. TeamViewer)":
        return 7
    
df["Obtain_accessR"] = df["Obtain_access"].apply(Obtain_access_recode)

# %% [markdown]
# #### Verify that recoding has been applied for Obtain_access variable
# #### NaN values in the recoded column

# %%
df.head()
# Out:
#    ID Prior_WFH             Devices      Device_owner  \
# 0   5       Yes             Laptop;  Corporate assets
# 1   6       Yes             Laptop;  Corporate assets
# 2   7       Yes  Laptop;Smartphone;   Personal assets
# 3   8       Yes             Laptop;  Corporate assets
# 4   9       Yes  Laptop;Smartphone;  Corporate assets
#
#                                        Obtain_access New_apps Collab_solution  \
# 0  Remote connection to your workstation (e.g. Te...       No             Yes
# 1                              No special provisions       No             Yes
# 2                              No special provisions       No              No
# 3                              No special provisions       No              No
# 4                                         VPN access       No             Yes
#
#   Prefer_WFH Productivity Collab_colleagues  ...       Proud_WFO  \
# 0   Disagree    Undecided          Disagree  ...           Agree
# ...

# %% [markdown]
# ####     Use .unique() to show recoded values
# #### original array (7,5,6,2,nan, 1,4,3) the nan = 0

# %%
df['Obtain_accessR'].unique()
# Out:
# array([7, 5, 6, 2, 0, 1, 4, 3])

# %% [markdown]
# #### Use .unique() to show original category titles - shows extra space
# #### Copy/Paste 'Using VPN ' and replace the string in the above recode to remove nan

# %%
df['Obtain_access'].unique()
# Out:
# array(['Remote connection to your workstation (e.g. TeamViewer)',
#        'No special provisions', 'VPN access', 'Direct access',
#        'Using VPN ',
#        'Using 3rd party cloud solutions (e.g. G Cloud, Microsoft 365)',
#        'No Access', 'Other'], dtype=object)

# %% [markdown]
# #### check to see if nan was truly removed

# %%
df.isnull().sum()
# Out:
# ID                            0
# Prior_WFH                     0
# Devices                       0
# Device_owner                  0
# Obtain_access                 0
# New_apps                      0
# Collab_solution               0
# Prefer_WFH                    0
# Productivity                  0
# Collab_colleagues             0
# Satisfaction_with_approach    0
# Tech_support                  0
# Proud_WFO                     0
# Proper_access                 0
# Age                           0
# Education                     0
# Business_domain               0
# Title                         0
# Prior_WFHR                    0
# DevicesR                      0
# Device_ownerR                 0
# Obtain_accessR                0
# dtype: int64

# %% [markdown]
# ### Were you asked to use applications or services that you were unfamiliar with because of the need for remote working?
# #### Recoding for New_apps variable

# %%
def New_apps_recode (series):
    if series == "No":
        return 0
    if series == "Yes":
        return 1
df["New_appsR"]= df["New_apps"].apply(New_apps_recode)

# %% [markdown]
# #### Verify that recoding has been applied for New_apps variable

# %%
df.head()
# Out:
#    ID Prior_WFH             Devices      Device_owner  \
# 0   5       Yes             Laptop;  Corporate assets
# 1   6       Yes             Laptop;  Corporate assets
# 2   7       Yes  Laptop;Smartphone;   Personal assets
# 3   8       Yes             Laptop;  Corporate assets
# 4   9       Yes  Laptop;Smartphone;  Corporate assets
#
#                                        Obtain_access New_apps Collab_solution  \
# 0  Remote connection to your workstation (e.g. Te...       No             Yes
# 1                              No special provisions       No             Yes
# 2                              No special provisions       No              No
# 3                              No special provisions       No              No
# 4                                         VPN access       No             Yes
#
#   Prefer_WFH Productivity Collab_colleagues  ...   Proper_access  \
# 0   Disagree    Undecided          Disagree  ...           Agree
# ...

# %% [markdown]
# ### Has your company adopted a specific collaboration solution?
# #### Use value_counts() to discover how many answered the question, how and the data type

# %%
df.Collab_solution.value_counts()
# Out:
# Yes    169
# No      92
# Name: Collab_solution, dtype: int64

# %% [markdown]
# #### create a new column of recoded data and add to the data set

# %%
def Collab_solution_recode (series):
    if series == "No":
        return 0
    if series == "Yes":
        return 1
df["Collab_solutionR"]= df["Collab_solution"].apply(Collab_solution_recode)

# %% [markdown]
# #### print the data frame to verify the recoded column was added to the data

# %%
df.head()
# Out:
#    ID Prior_WFH             Devices      Device_owner  \
# 0   5       Yes             Laptop;  Corporate assets
# 1   6       Yes             Laptop;  Corporate assets
# 2   7       Yes  Laptop;Smartphone;   Personal assets
# 3   8       Yes             Laptop;  Corporate assets
# 4   9       Yes  Laptop;Smartphone;  Corporate assets
#
#                                        Obtain_access New_apps Collab_solution  \
# 0  Remote connection to your workstation (e.g. Te...       No             Yes
# 1                              No special provisions       No             Yes
# 2                              No special provisions       No              No
# 3                              No special provisions       No              No
# 4                                         VPN access       No             Yes
#
#   Prefer_WFH Productivity Collab_colleagues  ...              Age  \
# 0   Disagree    Undecided          Disagree  ...  25-34 years old
# ...

# %% [markdown]
# ### I prefer working from home more than going to the office.
# #### Use value_counts() to discover how many answered the question, how and the data type

# %%
df.Prefer_WFH.value_counts()
# Out:
# Agree                77
# Undecided            67
# Disagree             54
# Strongly agree       47
# Strongly disagree    16
# Name: Prefer_WFH, dtype: int64

# %% [markdown]
# #### create a new column of recoded data and add to the data set

# %%
def Prefer_WFH_recode (series):
    if series == "Strongly agree":
        return 0
    if series == "Agree":
        return 1
    if series == "Undecided":
        return 2
    if series == "Disagree":
        return 3
    if series == "Strongly disagree":
        return 4
    
df["Prefer_WFHR"]= df["Prefer_WFH"].apply(Prefer_WFH_recode)

# %% [markdown]
# #### print the data frame to verify the recoded column was added to the data

# %%
df.head()
# Out:
#    ID Prior_WFH             Devices      Device_owner  \
# 0   5       Yes             Laptop;  Corporate assets
# 1   6       Yes             Laptop;  Corporate assets
# 2   7       Yes  Laptop;Smartphone;   Personal assets
# 3   8       Yes             Laptop;  Corporate assets
# 4   9       Yes  Laptop;Smartphone;  Corporate assets
#
#                                        Obtain_access New_apps Collab_solution  \
# 0  Remote connection to your workstation (e.g. Te...       No             Yes
# 1                              No special provisions       No             Yes
# 2                              No special provisions       No              No
# 3                              No special provisions       No              No
# 4                                         VPN access       No             Yes
#
#   Prefer_WFH Productivity Collab_colleagues  ...         Education  \
# 0   Disagree    Undecided          Disagree  ...   Master’s degree
# ...

# %% [markdown]
# ### I work more productively from home.
# #### Determine levels for Productivity variable

# %%
df.Productivity.value_counts()
# Out:
# Undecided            76
# Agree                76
# Disagree             51
# Strongly agree       40
# Strongly disagree    18
# Name: Productivity, dtype: int64

# %% [markdown]
# #### Recoding for Productivity variable

# %%
def Productivity_recode (series):
    if series == "Strongly agree":
        return 0
    if series == "Agree":
        return 1
    if series == "Undecided":
        return 2
    if series == "Disagree":
        return 3
    if series == "Strongly disagree":
        return 4
    
df["ProductivityR"]= df["Productivity"].apply(Productivity_recode)

# %% [markdown]
# #### Verify recoding has been applied for Productivity variable

# %%
df.head()
# Out:
#    ID Prior_WFH             Devices      Device_owner  \
# 0   5       Yes             Laptop;  Corporate assets
# 1   6       Yes             Laptop;  Corporate assets
# 2   7       Yes  Laptop;Smartphone;   Personal assets
# 3   8       Yes             Laptop;  Corporate assets
# 4   9       Yes  Laptop;Smartphone;  Corporate assets
#
#                                        Obtain_access New_apps Collab_solution  \
# 0  Remote connection to your workstation (e.g. Te...       No             Yes
# 1                              No special provisions       No             Yes
# 2                              No special provisions       No              No
# 3                              No special provisions       No              No
# 4                                         VPN access       No             Yes
#
#   Prefer_WFH Productivity Collab_colleagues  ...       Business_domain  \
# 0   Disagree    Undecided          Disagree  ...  Education & Research
# ...

# %% [markdown]
# ### I collaborate with my colleagues as effectively as when we are in office.
# #### Use value_counts() to discover how many answered the question, how and the data type

# %%
df.Collab_colleagues.value_counts()
# Out:
# Agree                101
# Disagree              70
# Undecided             39
# Strongly agree        36
# Strongly disagree     15
# Name: Collab_colleagues, dtype: int64

# %% [markdown]
# #### create a new column of recoded data and add to the data set

# %%
def Collab_colleagues_recode (series):
    if series == "Strongly agree":
        return 0
    if series == "Agree":
        return 1
    if series == "Undecided":
        return 2
    if series == "Disagree":
        return 3
    if series == "Strongly disagree":
        return 4
    
df["Collab_colleaguesR"]= df["Collab_colleagues"].apply(Collab_colleagues_recode)

# %% [markdown]
# #### print the data frame to verify the recoded column was added to the data

# %%
df.head()
# Out:
#    ID Prior_WFH             Devices      Device_owner  \
# 0   5       Yes             Laptop;  Corporate assets
# 1   6       Yes             Laptop;  Corporate assets
# 2   7       Yes  Laptop;Smartphone;   Personal assets
# 3   8       Yes             Laptop;  Corporate assets
# 4   9       Yes  Laptop;Smartphone;  Corporate assets
#
#                                        Obtain_access New_apps Collab_solution  \
# 0  Remote connection to your workstation (e.g. Te...       No             Yes
# 1                              No special provisions       No             Yes
# 2                              No special provisions       No              No
# 3                              No special provisions       No              No
# 4                                         VPN access       No             Yes
#
#   Prefer_WFH Productivity Collab_colleagues  ...            Title Prior_WFHR  \
# 0   Disagree    Undecided          Disagree  ...       Researcher          1
# ...

# %% [markdown]
# ### I am satisfied by my employers approach to the crisis.
# #### Determine levels for Statisfaction_with_approach variable

# %%
df.Satisfaction_with_approach.value_counts()
# Out:
# Agree                107
# Strongly agree       105
# Undecided             25
# Disagree              16
# Strongly disagree      8
# Name: Satisfaction_with_approach, dtype: int64

# %% [markdown]
# #### Recoding for Satisfaction_with_approach

# %%
def Satisfaction_with_approach_recode (series):
    if series == "Strongly agree":
        return 0
    if series == "Agree":
        return 1
    if series == "Strongly disagree":
        return 2
    if series == "Disagree":
        return 3
    if series == "Undecided":
        return 4
    
df["Satisfaction_with_approachR"]= df["Satisfaction_with_approach"].apply(Satisfaction_with_approach_recode)

# %% [markdown]
# #### Verify that recoding applied for Statisfaction_with_approach

# %%
df.head()
# Out:
#    ID Prior_WFH             Devices      Device_owner  \
# 0   5       Yes             Laptop;  Corporate assets
# 1   6       Yes             Laptop;  Corporate assets
# 2   7       Yes  Laptop;Smartphone;   Personal assets
# 3   8       Yes             Laptop;  Corporate assets
# 4   9       Yes  Laptop;Smartphone;  Corporate assets
#
#                                        Obtain_access New_apps Collab_solution  \
# 0  Remote connection to your workstation (e.g. Te...       No             Yes
# 1                              No special provisions       No             Yes
# 2                              No special provisions       No              No
# 3                              No special provisions       No              No
# 4                                         VPN access       No             Yes
#
#   Prefer_WFH Productivity Collab_colleagues  ... Prior_WFHR DevicesR  \
# 0   Disagree    Undecided          Disagree  ...          1        0
# ...

# %% [markdown]
# ### I have all the support I need to face any technical problems I have.
# #### Determine levels for Tech_support variable

# %%
df.Tech_support.value_counts()
# Out:
# Agree                112
# Strongly agree        82
# Undecided             31
# Disagree              28
# Strongly disagree      8
# Name: Tech_support, dtype: int64

# %% [markdown]
# #### Recoding for Tech_support variable

# %%
def Tech_support_recode (series):
    if series == "Strongly agree":
        return 0
    if series == "Agree":
        return 1
    if series == "Strongly disagree":
        return 2
    if series == "Disagree":
        return 3
    if series == "Undecided":
        return 4
    
df["Tech_supportR"] = df["Tech_support"].apply(Tech_support_recode)

# %% [markdown]
# #### Verify recoding applied for Tech_support variable

# %%
df.head()
# Out:
#    ID Prior_WFH             Devices      Device_owner  \
# 0   5       Yes             Laptop;  Corporate assets
# 1   6       Yes             Laptop;  Corporate assets
# 2   7       Yes  Laptop;Smartphone;   Personal assets
# 3   8       Yes             Laptop;  Corporate assets
# 4   9       Yes  Laptop;Smartphone;  Corporate assets
#
#                                        Obtain_access New_apps Collab_solution  \
# 0  Remote connection to your workstation (e.g. Te...       No             Yes
# 1                              No special provisions       No             Yes
# 2                              No special provisions       No              No
# 3                              No special provisions       No              No
# 4                                         VPN access       No             Yes
#
#   Prefer_WFH Productivity Collab_colleagues  ... DevicesR Device_ownerR  \
# 0   Disagree    Undecided          Disagree  ...        0             0
# ...

# %% [markdown]
# ### I am proud to work for my organization.
# #### Determine levels for Proud_WFO variable

# %%
df.Proud_WFO.value_counts()
# Out:
# Agree                105
# Strongly agree       101
# Undecided             42
# Disagree               9
# Strongly disagree      4
# Name: Proud_WFO, dtype: int64

# %% [markdown]
# #### Recoding for Proud_WFO variable

# %%
def Proud_WFO_recode (series):
    if series == "Strongly agree":
        return 0
    if series == "Agree":
        return 1
    if series == "Undecided":
        return 2
    if series == "Disagree":
        return 3
    if series == "Strongly disagree":
        return 4
    
df["Proud_WFOR"]= df["Proud_WFO"].apply(Proud_WFO_recode)

# %% [markdown]
# #### Verify recoding applied to Proud_WFO variable

# %%
df.head()
# Out:
#    ID Prior_WFH             Devices      Device_owner  \
# 0   5       Yes             Laptop;  Corporate assets
# 1   6       Yes             Laptop;  Corporate assets
# 2   7       Yes  Laptop;Smartphone;   Personal assets
# 3   8       Yes             Laptop;  Corporate assets
# 4   9       Yes  Laptop;Smartphone;  Corporate assets
#
#                                        Obtain_access New_apps Collab_solution  \
# 0  Remote connection to your workstation (e.g. Te...       No             Yes
# 1                              No special provisions       No             Yes
# 2                              No special provisions       No              No
# 3                              No special provisions       No              No
# 4                                         VPN access       No             Yes
#
#   Prefer_WFH Productivity Collab_colleagues  ... Device_ownerR Obtain_accessR  \
# 0   Disagree    Undecided          Disagree  ...             0              7
# ...

# %% [markdown]
# ### I have access to the things I need to do my job well.
# #### Use value_counts() to discover how many answered the question, how and the data type

# %%
df.Proper_access.value_counts()
# Out:
# Strongly agree       117
# Agree                113
# Undecided             18
# Disagree              11
# Strongly disagree      2
# Name: Proper_access, dtype: int64

# %% [markdown]
# #### create a new column of recoded data and add to the data set

# %%
def Proper_access_recode (series):
    if series == "Strongly agree":
        return 0
    if series == "Agree":
        return 1
    if series == "Undecided":
        return 2
    if series == "Disagree":
        return 3
    if series == "Strongly disagree":
        return 4
    
df["Proper_accessR"]= df["Proper_access"].apply(Proper_access_recode)

# %% [markdown]
# #### print the data frame to verify the recoded column was added to the data

# %%
df.head()
# Out:
#    ID Prior_WFH             Devices      Device_owner  \
# 0   5       Yes             Laptop;  Corporate assets
# 1   6       Yes             Laptop;  Corporate assets
# 2   7       Yes  Laptop;Smartphone;   Personal assets
# 3   8       Yes             Laptop;  Corporate assets
# 4   9       Yes  Laptop;Smartphone;  Corporate assets
#
#                                        Obtain_access New_apps Collab_solution  \
# 0  Remote connection to your workstation (e.g. Te...       No             Yes
# 1                              No special provisions       No             Yes
# 2                              No special provisions       No              No
# 3                              No special provisions       No              No
# 4                                         VPN access       No             Yes
#
#   Prefer_WFH Productivity Collab_colleagues  ... Obtain_accessR New_appsR  \
# 0   Disagree    Undecided          Disagree  ...              7         0
# ...

# %% [markdown]
# ### Which best describes your age?
# #### Determine levels of Age variable

# %%
df.Age.value_counts()
# Out:
# 35-44 years old      111
# 25-34 years old       80
# 45-54 years old       48
# 55-64 years old       10
# 18-24 years old        9
# 75 years or older      2
# 65-74 years old        1
# Name: Age, dtype: int64

# %% [markdown]
# #### Recoding for Age variable

# %%
def Age_recode (series):
    if series == "18-24 years old":
        return 0
    if series == "25-34 years old":
        return 1
    if series == "35-44 years old":
        return 2
    if series == "45-54 years old":
        return 3
    if series == "55-64 years old":
        return 4
    if series == "65-74 years old":
        return 5
    if series == "75 years or older":
        return 6
    
df["AgeR"]= df["Age"].apply(Age_recode)

# %% [markdown]
# #### verify recoding applied for Age variable

# %%
df.head()
# Out:
#    ID Prior_WFH             Devices      Device_owner  \
# 0   5       Yes             Laptop;  Corporate assets
# 1   6       Yes             Laptop;  Corporate assets
# 2   7       Yes  Laptop;Smartphone;   Personal assets
# 3   8       Yes             Laptop;  Corporate assets
# 4   9       Yes  Laptop;Smartphone;  Corporate assets
#
#                                        Obtain_access New_apps Collab_solution  \
# 0  Remote connection to your workstation (e.g. Te...       No             Yes
# 1                              No special provisions       No             Yes
# 2                              No special provisions       No              No
# 3                              No special provisions       No              No
# 4                                         VPN access       No             Yes
#
#   Prefer_WFH Productivity Collab_colleagues  ... New_appsR Collab_solutionR  \
# 0   Disagree    Undecided          Disagree  ...         0                1
# ...

# %% [markdown]
# ### What is the highest degree or level of school you have completed?
# #### Use value_counts() to discover how many answered the question, how and the data type

# %%
df.Education.value_counts()
# Out:
# Master’s degree                                    130
# Doctorate degree                                    52
# Bachelor’s degree                                   41
# High school graduate, diploma or the equivalent     12
# Trade/technical/vocational training                 11
# Associate degree                                     6
# Professional degree                                  5
# Some college credit, no degree                       4
# Name: Education, dtype: int64

# %% [markdown]
# #### create a new column of recoded data and add to the data set

# %%
def Education_recode (series):
    if series == "High school graduate, diploma or the equivalent":
        return 0
    if series == "Trade/technical/vocational training":
        return 1
    if series == "Some college credit, no degree":
        return 2
    if series == "Associate degree":
        return 3
    if series == "Professional degree":
        return 4
    if series == "Bachelor’s degree":
        return 5
    if series == "Master’s degree":
        return 6
    if series == "Doctorate degree":
        return 7
    
    
df["EducationR"]= df["Education"].apply(Education_recode)

# %% [markdown]
# #### print the data frame to verify the recoded column was added to the data

# %%
df.head()
# Out:
#    ID Prior_WFH             Devices      Device_owner  \
# 0   5       Yes             Laptop;  Corporate assets
# 1   6       Yes             Laptop;  Corporate assets
# 2   7       Yes  Laptop;Smartphone;   Personal assets
# 3   8       Yes             Laptop;  Corporate assets
# 4   9       Yes  Laptop;Smartphone;  Corporate assets
#
#                                        Obtain_access New_apps Collab_solution  \
# 0  Remote connection to your workstation (e.g. Te...       No             Yes
# 1                              No special provisions       No             Yes
# 2                              No special provisions       No              No
# 3                              No special provisions       No              No
# 4                                         VPN access       No             Yes
#
#   Prefer_WFH Productivity Collab_colleagues  ... Collab_solutionR Prefer_WFHR  \
# 0   Disagree    Undecided          Disagree  ...                1           3
# ...

# %% [markdown]
# #### use .unique() to show recoded values
# #### original array showed nan value

# %%
df['EducationR'].unique()
# Out:
# array([6, 7, 0, 5, 3, 4, 1, 2])

# %% [markdown]
# #### Use .unique() to show original category titles
# #### Copy/Paste each category in the recode above to remove nan

# %%
df['Education'].unique()
# Out:
# array(['Master’s degree', 'Doctorate degree',
#        'High school graduate, diploma or the equivalent',
#        'Bachelor’s degree', 'Associate degree', 'Professional degree',
#        'Trade/technical/vocational training',
#        'Some college credit, no degree'], dtype=object)

# %% [markdown]
# #### Check to see if the nan was truly removed

# %%
df.isnull().sum()
# Out:
# ID                             0
# Prior_WFH                      0
# Devices                        0
# Device_owner                   0
# Obtain_access                  0
# New_apps                       0
# Collab_solution                0
# Prefer_WFH                     0
# Productivity                   0
# Collab_colleagues              0
# Satisfaction_with_approach     0
# Tech_support                   0
# Proud_WFO                      0
# Proper_access                  0
# Age                            0
# Education                      0
# Business_domain                0
# Title                          0
# Prior_WFHR                     0
# DevicesR                       0
# Device_ownerR                  0
# Obtain_accessR                 0
# New_appsR                      0
# Collab_solutionR               0
# Prefer_WFHR                    0
# ProductivityR                  0
# Collab_colleaguesR             0
# Satisfaction_with_approachR    0
# ...

# %% [markdown]
# ### Please select the business domain of the organization you work for
# #### Use value_counts() to discover how many answered the question, how and the data type

# %%
df.Business_domain.value_counts()
# Out:
# IT (Information Technology)                 70
# Education & Research                        57
# EPES (Electrical Power & Energy Systems)    40
# Other                                       36
# Telecommunications                          20
# Banking & Financial                         17
# Public Sector                               10
# Health                                       6
# Transport                                    4
# Security (cyber)                             1
# Name: Business_domain, dtype: int64

# %% [markdown]
# #### create a new column of recoded data and add to the data set

# %%
def Business_domain_recode (series):
    if series == "Banking & Financial":
        return 0
    if series == "Education & Research":
        return 1
    if series == "EPES (Electrical Power & Energy Systems)":
        return 2
    if series == "Health":
        return 3
    if series == "IT (Information Technology)":
        return 4
    if series == "Public Sector":
        return 5
    if series == "Security (cyber)":
        return 6
    if series == "Telecommunications":
        return 7
    if series == "Transport":
        return 8
    if series == "Other":
        return 9
    
df["Business_domainR"]= df["Business_domain"].apply(Business_domain_recode)

# %% [markdown]
# #### print the data frame to verify the recoded column was added to the data

# %%
df.head()
# Out:
#    ID Prior_WFH             Devices      Device_owner  \
# 0   5       Yes             Laptop;  Corporate assets
# 1   6       Yes             Laptop;  Corporate assets
# 2   7       Yes  Laptop;Smartphone;   Personal assets
# 3   8       Yes             Laptop;  Corporate assets
# 4   9       Yes  Laptop;Smartphone;  Corporate assets
#
#                                        Obtain_access New_apps Collab_solution  \
# 0  Remote connection to your workstation (e.g. Te...       No             Yes
# 1                              No special provisions       No             Yes
# 2                              No special provisions       No              No
# 3                              No special provisions       No              No
# 4                                         VPN access       No             Yes
#
#   Prefer_WFH Productivity Collab_colleagues  ... Prefer_WFHR ProductivityR  \
# 0   Disagree    Undecided          Disagree  ...           3             2
# ...

# %%
df.corr(method='pearson').style.format("{:.2}").background_gradient(cmap=plt.get_cmap('coolwarm'), axis=1)
# Out:
# <style  type="text/css" >
# #T_63133_row0_col0,#T_63133_row1_col1,#T_63133_row2_col2,#T_63133_row3_col3,#T_63133_row4_col4,#T_63133_row5_col5,#T_63133_row6_col6,#T_63133_row7_col7,#T_63133_row8_col8,#T_63133_row9_col9,#T_63133_row10_col10,#T_63133_row11_col11,#T_63133_row12_col12,#T_63133_row13_col13,#T_63133_row14_col14,#T_63133_row15_col15,#T_63133_row16_col16{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_63133_row0_col1,#T_63133_row1_col0,#T_63133_row2_col16,#T_63133_row3_col16,#T_63133_row4_col6,#T_63133_row4_col16,#T_63133_row5_col15,#T_63133_row6_col4,#T_63133_row7_col12,#T_63133_row8_col1,#T_63133_row8_col16,#T_63133_row9_col6,#T_63133_row10_col6,#T_63133_row11_col16,#T_63133_row12_col7,#T_63133_row13_col1,#T_63133_row14_col16,#T_63133_row15_col5,#T_63133_row16_col3{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }#T_63133_row0_col2,#T_63133_row1_col6,#T_63133_row6_col1,#T_63133_row8_col5{
# ...
